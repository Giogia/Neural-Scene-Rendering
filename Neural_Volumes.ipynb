# %% [markdown]
# <a href="https://colab.research.google.com/github/Giogia/Neural-Volumes/blob/master/Neural_Volumes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Init Colab location to repo
import os

directory = 'drive/My Drive/Colab/Neural-Volumes'

if os.getcwd() != '/content/' + directory:
  os.chdir(directory)

print('\n', 'Repository Content')
# %ls
# Out:
#  Repository Content
# data/  experiments/  Neural_volumes.ipynb  results/
# eval/  models/       render.py             train.py

# %%
# Apex Fix compatibility for Mixed Precision Training 
# !git clone https://www.github.com/nvidia/apex
'''
# %cd apex
# !python3 setup.py install
# %cd ../
'''
# Out:
# '\n%cd apex\n!python3 setup.py install\n%cd ../\n'

# %%
# !pip install openexr
# Out:
# ...
#   Created wheel for openexr: filename=OpenEXR-1.3.2-cp36-cp36m-linux_x86_64.whl size=188451 sha256=ba74697c8293ffe8949923ebd0a022b6b0340a2d51e4ee1d55c27d0b25f3ffc0
#   Stored in directory: /root/.cache/pip/wheels/41/06/9f/c7dc838815b0e7dfc7d7dc19cc3d677edb47594d8489adc62a
# Successfully built openexr
# ...

# %%
# !git fetch --all
# !git reset origin/master --hard
# !git pull
# Out:
# Fetching origin
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 9 (delta 5), reused 9 (delta 5), pack-reused 0
# Unpacking objects: 100% (9/9), done.
# From https://github.com/Giogia/Neural-Volumes
#    96d8f25..4e91bfd  master     -> origin/master
# Checking out files: 100% (2099/2099), done.
# HEAD is now at 4e91bfd Update blender.py
# Already up to date.

# %%
# !rm experiments/Fox/experiment4/log.txt

# %%
# !rm experiments/Fox/experiment4/*.jpg
# Out:
# rm: cannot remove 'experiments/Fox/experiment4/*.jpg': No such file or directory

# %%
# !python train.py experiments/Fox/experiment4/config.py
# Out:
# Python 3.6.9 (default, Apr 18 2020, 01:56:04)
# [GCC 8.4.0]
# PyTorch 1.5.0+cu101
# train.py experiments/Fox/experiment4/config.py
# Output path: experiments/Fox/experiment4
# Config loaded (0.02 s)
# Dataset instantiated (3.39 s)
# Writer instantiated (0.00 s)
# Autoencoder instantiated (4.75 s)
# Optimizer instantiated (0.00 s)
# Loss instantiated (0.00 s)
# Scheduler instantiated (0.00 s)
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3226: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
# Iteration 000000: lr = 0.00010, loss = 1.89182, kldiv = 0.00264, tvl1 = 0.04047, alphapr = -0.00000, irgbmse = 1.89141, iter/sec = 0.30
# ...

# %%
# !python render.py experiments/Fox/experiment4/config.py Render
# Out:
# render.py experiments/Fox/experiment4/config.py Render
# Output path: experiments/Fox/experiment4
# Config loaded (0.02 s)
# Dataset instantiated (0.01 s)
# Writer instantiated (0.07 s)
# Autoencoder instantiated (4.75 s)
# Training weights loaded (1.75 s)
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3226: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
#    0 /  100 (0.0198 iter/sec)
#   16 /  100 (0.0489 iter/sec)
#   32 /  100 (0.0489 iter/sec)
#   48 /  100 (0.0489 iter/sec)
#   64 /  100 (0.0489 iter/sec)
#   80 /  100 (0.0489 iter/sec)
#   96 /  100 (0.1597 iter/sec)
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
# ...
